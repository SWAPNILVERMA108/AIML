# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name":["Swapnil","Rahul","Mr. Brown"],
    "age" :[20,23,25],
    "sex": ["male","male","male"]
    
}
    
)
df
# Out:
#         Name  age   sex
# 0    Swapnil   20  male
# 1      Rahul   23  male
# 2  Mr. Brown   25  male

# %%
df["Name"]
# Out:
# 0      Swapnil
# 1        Rahul
# 2    Mr. Brown
# Name: Name, dtype: object

# %% [markdown]
# series

# %%
ages = pd.Series([22,23,26],name = "age")
ages
# Out:
# 0    22
# 1    23
# 2    26
# Name: age, dtype: int64

# %%
df1 = pd.Series([10,20,30,40,50])
print(df1)
print(df1[1])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 20

# %%
df2 = pd.Series([20,21,22,23,24],index=["Tom","bob","charlie","brown","thor"])
print(df2)
# Out:
# Tom        20
# bob        21
# charlie    22
# brown      23
# thor       24
# dtype: int64

# %% [markdown]
# properties of series

# %%
a1=pd.Series([1,23,3,56,9,7])
a2 = pd.Series([24,56,89,221,12,90])
print(a1+a2)
# Out:
# 0     25
# 1     79
# 2     92
# 3    277
# 4     21
# 5     97
# dtype: int64

# %% [markdown]
# Dataframe

# %%
df = pd.DataFrame({
    "Name":["Swapnil","Rahul","Mr. Brown"],
    "age" :[20,23,25],
    "sex": ["male","male","male"]
    
}
    
)
df
print(df, type(df))
print(df.index)
# Out:
#         Name  age   sex
# 0    Swapnil   20  male
# 1      Rahul   23  male
# 2  Mr. Brown   25  male <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)

# %%
df4= pd.DataFrame([["adam",34],["tom",56],["thor","55"]],columns=["Name","Age"])
print(df4)
# Out:
#    Name Age
# 0  adam  34
# 1   tom  56
# 2  thor  55

# %%
import numpy as np

# %%
n = np.array([[1,2,3],[4,5,6]])
print(n)
df5 = pd.DataFrame(n,columns=["a","b","c"])
print(df5)
# Out:
# [[1 2 3]
#  [4 5 6]]
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.read_csv("employee_data.csv")
print(df)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df.head() # first five rows
df.tail() # last five rows
df.sample()
# Out:
#    ID Name  Age Department  Salary
# 4   5  Eva   38         IT   65000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %% [markdown]
# AQI Dataset

# %%
df7 =pd.read_csv("globalAirQuality.csv")
df7
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df7.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#selection the data
df7["country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
df7["city"]
# Out:
# 0        New York
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
df7[["city","aqi"]]
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
df7
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
print(df7)
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# Slecting data

df7["country"]
df7[["city","aqi"]]
df7.loc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df7.loc[0:11]    # starting index : ending index (inclusive)
# Out:
#                      timestamp country      city  latitude  longitude    pm25  \
# 0   2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1   2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2   2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3   2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4   2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5   2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
# 6   2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
# 7   2025-11-05 01:25:17.554219      US  New York    40.713    -74.006  57.816
# 8   2025-11-05 02:25:17.554219      US  New York    40.713    -74.006  60.914
# 9   2025-11-05 03:25:17.554219      US  New York    40.713    -74.006  16.464
# 10  2025-11-05 04:25:17.554219      US  New York    40.713    -74.006  48.469
# ...

# %%
df7.iloc[0:7]  # starting index : ending index (exclusive)
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5  2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
# 6  2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# ...

# %%
df7.loc[0:5,["city","aqi","country"]]
# Out:
#        city  aqi country
# 0  New York  108      US
# 1  New York   90      US
# 2  New York   84      US
# 3  New York  158      US
# 4  New York   97      US
# 5  New York   92      US

# %%
# use of iat and at
df7.iat[0,4]  # row index and column index
# Out:
# np.float64(-74.006)

# %%
df7.at[0,"city"]  # row label and column label
df7.iat[0,2]
# Out:
# 'New York'

# %%
cities = df7["city"].copy()
cities[0]="mumbai"

# %%
cities
# Out:
# 0          mumbai
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
# Filtering the data 
df7[df7["aqi"]<70]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 22     2025-11-05 16:25:17.554219      US  New York    40.713    -74.006
# 36     2025-11-06 06:25:17.554219      US  New York    40.713    -74.006
# 40     2025-11-06 10:25:17.554219      US  New York    40.713    -74.006
# 43     2025-11-06 13:25:17.554219      US  New York    40.713    -74.006
# 45     2025-11-06 15:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17969  2025-11-18 11:25:17.554219      CH    Zurich    47.377      8.542
# 17973  2025-11-18 15:25:17.554219      CH    Zurich    47.377      8.542
# 17979  2025-11-18 21:25:17.554219      CH    Zurich    47.377      8.542
# 17986  2025-11-19 04:25:17.554219      CH    Zurich    47.377      8.542
# 17990  2025-11-19 08:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df7[(df7["aqi"]>50) & (df7["temperature"]<30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# 5      2025-11-04 23:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
aqi_data = df7[(df7["aqi"]>50) & (df7["temperature"]<100)]
aqi_data.iloc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
aqi_data.loc[2]
# Out:
# timestamp      2025-11-04 20:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                                42.25
# pm10                               82.553
# no2                                26.935
# so2                                 9.538
# o3                                  23.32
# co                                  0.977
# aqi                                    84
# temperature                        31.833
# humidity                           62.783
# wind_speed                           9.65
# Name: 2, dtype: object

# %% [markdown]
# Query

# %%
df7.query("aqi>50 and temperature<20")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# 5      2025-11-04 23:25:17.554219      US  New York    40.713    -74.006
# 9      2025-11-05 03:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17988  2025-11-19 06:25:17.554219      CH    Zurich    47.377      8.542
# 17989  2025-11-19 07:25:17.554219      CH    Zurich    47.377      8.542
# 17992  2025-11-19 10:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df7.query("aqi>50 and temperature<20")[["city","aqi","temperature"]]
# Out:
#            city  aqi  temperature
# 0      New York  108       18.504
# 1      New York   90        5.838
# 4      New York   97       13.632
# 5      New York   92       15.159
# 9      New York   76       11.490
# ...         ...  ...          ...
# 17988    Zurich  122       13.982
# 17989    Zurich   93       10.150
# 17992    Zurich   91       14.728
# 17995    Zurich  103        7.079
# 17999    Zurich   88        8.529
#
# [8095 rows x 3 columns]

# %%
aqi_temp =30
df7.query("aqi>50 and temperature<@aqi_temp")[["city","aqi","temperature"]]
# Out:
#            city  aqi  temperature
# 0      New York  108       18.504
# 1      New York   90        5.838
# 3      New York  158       23.140
# 4      New York   97       13.632
# 5      New York   92       15.159
# ...         ...  ...          ...
# 17995    Zurich  103        7.079
# 17996    Zurich  105       28.734
# 17997    Zurich  122       21.951
# 17998    Zurich   95       24.042
# 17999    Zurich   88        8.529
#
# [13522 rows x 3 columns]

# %%
df =pd.read_csv("raw_data.csv")
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df.isnull()
# Out:
#        id   name    age  country  gender  income
# 0   False  False  False    False   False   False
# 1   False  False  False    False   False   False
# 2   False  False   True    False   False   False
# 3   False  False   True    False   False   False
# 4   False  False  False    False   False    True
# 5   False  False  False    False   False   False
# 6   False   True  False    False   False   False
# 7   False  False  False     True   False   False
# 8   False  False  False    False   False   False
# 9   False  False   True    False   False   False
# 10  False  False  False    False    True   False

# %%
df.isnull().sum() # count the number of missing values in each column
# Out:
# id         0
# name       1
# age        3
# country    1
# gender     1
# income     1
# dtype: int64

# %%
df.dropna() # drop the rows with missing values
# Out:
#    id        name   age country  gender   income
# 0   1    John Doe  29.0     USA    Male  55000.0
# 1   1    John Doe  29.0     USA    Male  55000.0
# 5   5      Li Wei  27.0   China    Male  51000.0
# 8   8  Rachel Lee  29.0     USA  Female  62000.0

# %%
df.fillna(0) # fill the missing values with 0
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   0.0  Canada   Female  62000.0
# 3    3          Alex   0.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      0.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6             0  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0       0     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA        0  58000.0

# %%
df.fillna(90)
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  90.0  Canada   Female  62000.0
# 3    3          Alex  90.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female     90.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6            90  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0      90     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  90.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA       90  58000.0

# %%
df["age"].fillna(12)
# Out:
# 0     29.0
# 1     29.0
# 2     12.0
# 3     12.0
# 4     34.0
# 5     27.0
# 6     45.0
# 7     38.0
# 8     29.0
# 9     12.0
# 10    31.0
# Name: age, dtype: float64

# %%
df.ffill() # forward fill the missing values
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  29.0  Canada   Female  62000.0
# 3    3          Alex  29.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  47000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6        Li Wei  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0   India     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  29.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA     Male  58000.0

# %%
df.bfill() # backward fill the missing values
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# handle duplicate values

df[["gender","country"]]
# Out:
#      gender country
# 0      Male     USA
# 1      Male     USA
# 2    Female  Canada
# 3   Unknown     USA
# 4    Female   Spain
# 5      Male   China
# 6    Female   India
# 7      Male     NaN
# 8    Female     USA
# 9      Male  Mexico
# 10      NaN     USA

# %%
df[["gender","country"]].duplicated()
df2= df.copy()

df.drop_duplicates(inplace=True)
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# DataTypes

df.dtypes
# Out:
# id           int64
# name        object
# age        float64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
df2 = df.copy()
df2 = df2.fillna(0)
df2 = df2["age"].astype("int64").copy()
df2.dtypes
# Out:
# dtype('int64')

# %%
df2
# Out:
# 0     29
# 2      0
# 3      0
# 4     34
# 5     27
# 6     45
# 7     38
# 8     29
# 9      0
# 10    31
# Name: age, dtype: int64

# %%
date_str = "2023-01-01"
type(date_str)
# Out:
# str

# %%
date_str = pd.Series([pd.to_datetime("2023-01-01")])
type(date_str.dtypes)
# Out:
# numpy.dtypes.DateTime64DType

# %%
df["gender"].str.upper()
# Out:
# 0        MALE
# 2      FEMALE
# 3     UNKNOWN
# 4      FEMALE
# 5        MALE
# 6      FEMALE
# 7        MALE
# 8      FEMALE
# 9        MALE
# 10        NaN
# Name: gender, dtype: object

# %%
df["gender"].str.capitalize()
# Out:
# 0        Male
# 2      Female
# 3     Unknown
# 4      Female
# 5        Male
# 6      Female
# 7        Male
# 8      Female
# 9        Male
# 10        NaN
# Name: gender, dtype: object

# %%
df["name"].str.split("Ga")
# Out:
# 0         [John Doe]
# 2       [Jane Smith]
# 3             [Alex]
# 4     [Maria , rcia]
# 5           [Li Wei]
# 6                NaN
# 7       [Ahmed Khan]
# 8       [Rachel Lee]
# 9      [Carlos Ruiz]
# 10     [Emily Davis]
# Name: name, dtype: object

# %%
df["name"].str.strip()
# Out:
# 0         John Doe
# 2       Jane Smith
# 3             Alex
# 4     Maria Garcia
# 5           Li Wei
# 6              NaN
# 7       Ahmed Khan
# 8       Rachel Lee
# 9      Carlos Ruiz
# 10     Emily Davis
# Name: name, dtype: object

# %%
df["country"].str.contains("india",case=False)
# Out:
# 0     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#Transforming Data (Feature Engineering)

df2 = df.copy()


df2["tax"]= df2["income"].apply(lambda x:"20%" if x>=50000 else "10%")
df2
# Out:
#     id          name   age country   gender   income  tax
# 0    1      John Doe  29.0     USA     Male  55000.0  20%
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5    5        Li Wei  27.0   China     Male  51000.0  20%
# 6    6           NaN  45.0   India   Female  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
gender_map = {"Male":"M","Female":"F","Unknown":"U"}
df2["gender"].map(gender_map)
# Out:
# 0       M
# 2       F
# 3       U
# 4       F
# 5       M
# 6       F
# 7       M
# 8       F
# 9       M
# 10    NaN
# Name: gender, dtype: object

# %%
df2.assign(new_income=df2["income"]*1.1)
# Out:
#     id          name   age country   gender   income  tax  new_income
# 0    1      John Doe  29.0     USA     Male  55000.0  20%     60500.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%     68200.0
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%     51700.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%         NaN
# 5    5        Li Wei  27.0   China     Male  51000.0  20%     56100.0
# 6    6           NaN  45.0   India   Female  73000.0  20%     80300.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%     74800.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%     68200.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%     49500.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  20%     63800.0

# %%
df2 = df2["country"].replace("usa","united state")

# %%
df2.columns =["Id","Name","Age","Country","Gender","Income","Tax","New_Income"]

# %%
#df2.rename(columns={"Income":"Salary"})

# %%
df2.rename(index={1:"First"})
# Out:
# 0        USA
# 2     Canada
# 3        USA
# 4      Spain
# 5      China
# 6      India
# 7        NaN
# 8        USA
# 9     Mexico
# 10       USA
# Name: country, dtype: object

# %%
# rename column
df2.columns=["sid","NaMe","AgE","Country","Gender","InCome","Tax"]

# %%
df2
# Out:
#     id          name   age country   gender   income  tax
# 0    1      John Doe  29.0     USA     Male  55000.0  20%
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5    5        Li Wei  27.0   China     Male  51000.0  20%
# 6    6           NaN  45.0   India   Female  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
df2
# Out:
#     sid          NaMe   AgE Country   Gender   InCome  Tax
# 0     1      John Doe  29.0     USA     Male  55000.0  20%
# 2     2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3     3          Alex   NaN     USA  Unknown  47000.0  10%
# 4     4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5     5        Li Wei  27.0   China     Male  51000.0  20%
# 6     6           NaN  45.0   India   Female  73000.0  20%
# 7     7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8     8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9     9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10   10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
df2.rename(columns={"InCome":"Salary"})
# Out:
#     sid          NaMe   AgE Country   Gender   Salary  Tax
# 0     1      John Doe  29.0     USA     Male  55000.0  20%
# 2     2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3     3          Alex   NaN     USA  Unknown  47000.0  10%
# 4     4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5     5        Li Wei  27.0   China     Male  51000.0  20%
# 6     6           NaN  45.0   India   Female  73000.0  20%
# 7     7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8     8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9     9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10   10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
df2.rename(index={2:"Two"})
# Out:
#      sid          NaMe   AgE Country   Gender   InCome  Tax
# 0      1      John Doe  29.0     USA     Male  55000.0  20%
# Two    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3      3          Alex   NaN     USA  Unknown  47000.0  10%
# 4      4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5      5        Li Wei  27.0   China     Male  51000.0  20%
# 6      6           NaN  45.0   India   Female  73000.0  20%
# 7      7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8      8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9      9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10    10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
sorted_df=df2["InCome"].sort_values()
df2 =df2.fillna(100)
sorted_df = df2.sort_values(["InCome","AgE"])

# %%
sorted_df.sort_index()
# Out:
#     sid          NaMe    AgE Country   Gender   InCome  Tax
# 0     1      John Doe   29.0     USA     Male  55000.0  20%
# 2     2    Jane Smith  100.0  Canada   Female  62000.0  20%
# 3     3          Alex  100.0     USA  Unknown  47000.0  10%
# 4     4  Maria Garcia   34.0   Spain   Female    100.0  10%
# 5     5        Li Wei   27.0   China     Male  51000.0  20%
# 6     6           100   45.0   India   Female  73000.0  20%
# 7     7    Ahmed Khan   38.0     100     Male  68000.0  20%
# 8     8    Rachel Lee   29.0     USA   Female  62000.0  20%
# 9     9   Carlos Ruiz  100.0  Mexico     Male  45000.0  10%
# 10   10   Emily Davis   31.0     USA      100  58000.0  20%

# %%
sorted_df.reset_index()
sorted_df.reset_index(drop=True)
# Out:
#    sid          NaMe    AgE Country   Gender   InCome  Tax
# 0    4  Maria Garcia   34.0   Spain   Female    100.0  10%
# 1    9   Carlos Ruiz  100.0  Mexico     Male  45000.0  10%
# 2    3          Alex  100.0     USA  Unknown  47000.0  10%
# 3    5        Li Wei   27.0   China     Male  51000.0  20%
# 4    1      John Doe   29.0     USA     Male  55000.0  20%
# 5   10   Emily Davis   31.0     USA      100  58000.0  20%
# 6    8    Rachel Lee   29.0     USA   Female  62000.0  20%
# 7    2    Jane Smith  100.0  Canada   Female  62000.0  20%
# 8    7    Ahmed Khan   38.0     100     Male  68000.0  20%
# 9    6           100   45.0   India   Female  73000.0  20%

# %%
sorted_df["ranking"] = sorted_df["InCome"].rank(ascending=False,method="min")

# %%
sorted_df
# Out:
#     sid          NaMe    AgE Country   Gender   InCome  Tax  ranking
# 4     4  Maria Garcia   34.0   Spain   Female    100.0  10%     10.0
# 9     9   Carlos Ruiz  100.0  Mexico     Male  45000.0  10%      9.0
# 3     3          Alex  100.0     USA  Unknown  47000.0  10%      8.0
# 5     5        Li Wei   27.0   China     Male  51000.0  20%      7.0
# 0     1      John Doe   29.0     USA     Male  55000.0  20%      6.0
# 10   10   Emily Davis   31.0     USA      100  58000.0  20%      5.0
# 8     8    Rachel Lee   29.0     USA   Female  62000.0  20%      3.0
# 2     2    Jane Smith  100.0  Canada   Female  62000.0  20%      3.0
# 7     7    Ahmed Khan   38.0     100     Male  68000.0  20%      2.0
# 6     6           100   45.0   India   Female  73000.0  20%      1.0

# %%
df2=df.copy()

# %%
new_col_order = [col for col in df2.columns if col != "id"] + ["id"]
new_col_order
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']

# %%
df2 = df.copy()

# %%
df2 = df2.drop_duplicates()

# %%
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2 = df2.fillna(0)

# %%
df2.sort_values("income")
df2= df2.reset_index(drop = True)

# %%
df2
# Out:
#    id          name   age country   gender   income
# 0   1      John Doe  29.0     USA     Male  55000.0
# 1   2    Jane Smith   0.0  Canada   Female  62000.0
# 2   3          Alex   0.0     USA  Unknown  47000.0
# 3   4  Maria Garcia  34.0   Spain   Female      0.0
# 4   5        Li Wei  27.0   China     Male  51000.0
# 5   6             0  45.0   India   Female  73000.0
# 6   7    Ahmed Khan  38.0       0     Male  68000.0
# 7   8    Rachel Lee  29.0     USA   Female  62000.0
# 8   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 9  10   Emily Davis  31.0     USA        0  58000.0

# %%
df2.to_csv("sorted_data.csv")

# %%
# Grouping and aggregation of data
df.groupby("country")["income"].mean()
# Out:
# country
# Canada    62000.0
# China     51000.0
# India     73000.0
# Mexico    45000.0
# Spain         NaN
# USA       55500.0
# Name: income, dtype: float64

# %%
df.groupby("country")["income"].min()
# Out:
# country
# Canada    62000.0
# China     51000.0
# India     73000.0
# Mexico    45000.0
# Spain         NaN
# USA       47000.0
# Name: income, dtype: float64

# %%
df.groupby("country")["income"].max()
# Out:
# country
# Canada    62000.0
# China     51000.0
# India     73000.0
# Mexico    45000.0
# Spain         NaN
# USA       62000.0
# Name: income, dtype: float64

# %%
df.groupby("gender")["income"].min()
# Out:
# gender
# Female     62000.0
# Male       45000.0
# Unknown    47000.0
# Name: income, dtype: float64

# %%
df.groupby("gender")["income"].count()
# Out:
# gender
# Female     3
# Male       4
# Unknown    1
# Name: income, dtype: int64

# %%
df.groupby("country")["income"].agg(["min","max","mean"])
# or
df.groupby("country")["income"].agg(min_salary="min",max_salary = "max",avg_salary="mean")
# Out:
#          min_salary  max_salary  avg_salary
# country
# Canada      62000.0     62000.0     62000.0
# China       51000.0     51000.0     51000.0
# India       73000.0     73000.0     73000.0
# Mexico      45000.0     45000.0     45000.0
# Spain           NaN         NaN         NaN
# USA         47000.0     62000.0     55500.0

# %%
df= pd.DataFrame({
    "country":["USA","USA","INDIA","INDIA"],
    "year":[2020,2021,2020,2021],
    "sales":[100,120,90,110],
    "profit":[20,25,18,22],
    "tax":[20,30,10,25]
    
    
})

# %%
melted_df = df.melt(
    id_vars=["country","year"],
    value_vars=["sales","profit","tax"],
    var_name="matrix",  
    value_name="value"
)

# %%
original_=melted_df.pivot(
    index = ["country","year"],
    columns="matrix",
    values= "value"
    
                          )
melted_df
# Out:
#    country  year  matrix  value
# 0      USA  2020   sales    100
# 1      USA  2021   sales    120
# 2    INDIA  2020   sales     90
# 3    INDIA  2021   sales    110
# 4      USA  2020  profit     20
# 5      USA  2021  profit     25
# 6    INDIA  2020  profit     18
# 7    INDIA  2021  profit     22
# 8      USA  2020     tax     20
# 9      USA  2021     tax     30
# 10   INDIA  2020     tax     10
# 11   INDIA  2021     tax     25

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data.csv")

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter",x="Age",y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# Merging and joining of data

# %%
df_customers = pd.DataFrame({
"customer_id": [1, 2, 3, 4],
"name": ["Adam", "Bob", "Charlie", "Dave"]
})

df_orders = pd.DataFrame({
"order_id": [101, 102, 103, 104],
"customer_id": [2, 1, 4, 5],
"amount": [250, 120, 300, 180]
})

# %%
df_customers
# Out:
#    customer_id     name
# 0            1     Adam
# 1            2      Bob
# 2            3  Charlie
# 3            4     Dave

# %%
df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            2     250
# 1       102            1     120
# 2       103            4     300
# 3       104            5     180

# %%
pd.merge(df_customers,df_orders,on="customer_id")
# Out:
#    customer_id  name  order_id  amount
# 0            1  Adam       102     120
# 1            2   Bob       101     250
# 2            4  Dave       103     300

# %%
# left join
pd.merge(df_customers,df_orders,on="customer_id",how="left")
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="right")
# Out:
#    customer_id  name  order_id  amount
# 0            2   Bob       101     250
# 1            1  Adam       102     120
# 2            4  Dave       103     300
# 3            5   NaN       104     180

# %%
pd.merge(df_customers,df_orders,on="customer_id",how="outer")
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0
# 4            5      NaN     104.0   180.0

# %% [markdown]
# Concatenation of DATA

# %%
df1 = pd.DataFrame({
    "id":[1,2,3],
    "name":["adam","tom","john"],

    
})
df2 = pd.DataFrame({
    "id":[4,5,6],
    "name":["mohan","alice","gopal"],

    
})

# %%
df1
# Out:
#    id  name
# 0   1  adam
# 1   2   tom
# 2   3  john

# %%
df2
# Out:
#    id   name
# 0   4  mohan
# 1   5  alice
# 2   6  gopal

# %%
pd.concat([df1,df2])
# Out:
#    id   name
# 0   1   adam
# 1   2    tom
# 2   3   john
# 0   4  mohan
# 1   5  alice
# 2   6  gopal

# %%
pd.concat([df1,df2],ignore_index="True")
# Out:
#    id   name
# 0   1   adam
# 1   2    tom
# 2   3   john
# 3   4  mohan
# 4   5  alice
# 5   6  gopal

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    id  name  id   name
# 0   1  adam   4  mohan
# 1   2   tom   5  alice
# 2   3  john   6  gopal
